# %%
# !pip install requests beautifulsoup4

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from bs4 import Tag

# %%
def element_to_md(element, service_link = "https://gic.gov.lk/", indent=0):
    md = ""
    prefix = "  " * indent

    if element.name == "p":
        # handle links inside <p>
        for a in element.find_all("a", href=True):
            absolute_url = urljoin(service_link, a['href'])
            a.replace_with(f"[{a.get_text(strip=True)}]({absolute_url})")
        text = element.get_text(" ", strip=True)
        md += f"{prefix}{text}\n\n"

    elif element.name in ["ul", "ol"]:
        for i, li in enumerate(element.find_all("li", recursive=False), start=1):
            # Nested lists
            sub_md = element_to_md(li, service_link, indent + 1)
            if element.name == "ul":
                md += f"{prefix}- {sub_md.strip()}\n"
            else:
                md += f"{prefix}{i}. {sub_md.strip()}\n"
        md += "\n"

    elif element.name == "li":
      # process li children
      for child in element.children:
          if isinstance(child, Tag):
              if child.name in ["p", "ul", "ol"]:
                  md += "\n" + element_to_md(child, service_link, indent + 1)
              else:
                  # process links
                  for a in child.find_all("a", href=True):
                      absolute_url = urljoin(service_link, a['href'])
                      a.replace_with(f"[{a.get_text(strip=True)}]({absolute_url})")
                  md += child.get_text(" ", strip=True) + " "
          else:
              # child is a string
              md += str(child).strip() + " "

    elif element.name == "table":
        # Skip if last table contains 'Organization Information'
        if "Organization Information" in element.get_text():
            return ""
        rows = element.find_all("tr")
        table_md = ""
        for r, row in enumerate(rows):
            cols = row.find_all(["th", "td"])
            row_text = " | ".join([c.get_text(" ", strip=True) for c in cols])
            table_md += f"{row_text}\n"
            if r == 0:
                # Add Markdown table separator after header
                table_md += " | ".join(["---"] * len(cols)) + "\n"
        md += table_md + "\n"

    elif element.name in ["div", "span"]:
        # Recursive call for children
        for child in element.children:
            md += element_to_md(child, service_link, indent)

    return md

# %%
def scrape_service_page(service_name, service_link):
    print(f"Scraping: {service_name}")
    try:
        resp = requests.get(service_link, timeout=30)
        resp.raise_for_status()
    except Exception as e:
        print(f"Failed to fetch {service_link}: {e}")
        return ""

    soup = BeautifulSoup(resp.text, "html.parser")
    content_div = soup.find("div", id="jf_content_print")
    if not content_div:
        print(f"No content div found for {service_link}")
        return

    md_text = element_to_md(content_div, service_link)
    # print(md_text)

    if (len(md_text) < 10):
        print(f"No content found for {service_link}")
        return ""
    else:
        # Save to markdown file
        safe_name = "".join([c if c.isalnum() else "_" for c in service_name])
        md_file_path = os.path.join(output_dir, f"{safe_name}.md")
        with open(md_file_path, "w", encoding="utf-8") as f:
            f.write(md_text)
            print(f"Saved to {md_file_path}: {len(md_text)}")
            return md_file_path

# %% [markdown]
# ## Scrape data for each main category

# %%
# Perform scraping one by one main category for easy human verification
# main_category_id = 1
# main_category_id = 2
# main_category_id = 3
# main_category_id = 4
# main_category_id = 5
# main_category_id = 6
# main_category_id = 7
# main_category_id = 8
# main_category_id = 9
# main_category_id = 10
# main_category_id = 11
main_category_id = 12

# %%
import pandas as pd

content = pd.read_csv(f'gic_data_content_{main_category_id-1}.csv')

# %%
output_dir = f"service_md_{main_category_id}"
os.makedirs(output_dir, exist_ok=True)

for idx, row in content.iterrows():
    try:
        if row["main_category_id"] != main_category_id:
            continue
        if pd.notna(row["content_file"]) and str(row["content_file"]).strip() != "":
          continue

        filename = scrape_service_page(
            row["service"],
            row["serviceLink"]
        )

        content.at[idx, "content_file"] = filename

    except Exception as e:
        print(f"Failed to scrape {row['serviceLink']}: {e}")
        content.at[idx, "content_file"] = ""
    print("\n----------------------------------------------------\n")
# Out:
# Scraping: Cooked Meals for People Subject to Distress
# Saved to service_md_12/Cooked_Meals_for_People_Subject_to_Distress.md: 1012
#
# ----------------------------------------------------
#
# Scraping: Funeral Aids In Respect of Those Who Died of Disaster
# Saved to service_md_12/Funeral_Aids_In_Respect_of_Those_Who_Died_of_Disaster.md: 1371
#
# ----------------------------------------------------
#
# Scraping: Obtaining Relief for Damages Caused to Crops Due to Any Disaster or Attack by Wild Elephant
# Saved to service_md_12/Obtaining_Relief_for_Damages_Caused_to_Crops_Due_to_Any_Disaster_or_Attack_by_Wild_Elephant.md: 1212
#
# ----------------------------------------------------
#
# Scraping: Obtaining Relief for Disasters Faces by Small Scale Entrepreneurs  and the Self Employed
# Saved to service_md_12/Obtaining_Relief_for_Disasters_Faces_by_Small_Scale_Entrepreneurs__and_the_Self_Employed.md: 996
#
# ----------------------------------------------------
#
# Scraping: Dry Rations Meals for People are Subject to Distress
# Saved to service_md_12/Dry_Rations_Meals_for_People_are_Subject_to_Distress.md: 974
#
# ----------------------------------------------------
#
# Scraping: Obtaining  Dry Ration Relief for Families of Fishermen  Disappeared in the Sea
# Saved to service_md_12/Obtaining__Dry_Ration_Relief_for_Families_of_Fishermen__Disappeared_in_the_Sea.md: 1225
#
# ----------------------------------------------------
#
# Scraping: Preparedness Planning
# Saved to service_md_12/Preparedness_Planning.md: 1802
#
# ----------------------------------------------------
#
# Scraping: Seismic Information
# Saved to service_md_12/Seismic_Information.md: 77
#
# ----------------------------------------------------
#
# Scraping: Analysis of Seismic Data and Tsunami Warnings
# Saved to service_md_12/Analysis_of_Seismic_Data_and_Tsunami_Warnings.md: 799
#
# ----------------------------------------------------
#
# Scraping: Disaster Mitigations and Risk Reduction services
# Saved to service_md_12/Disaster_Mitigations_and_Risk_Reduction_services.md: 1250
#
# ----------------------------------------------------
#
# Scraping: Training, Education & Public Awareness
# Saved to service_md_12/Training__Education___Public_Awareness.md: 1764
#
# ----------------------------------------------------
#
# Scraping: Early Warning Dissemination
# Saved to service_md_12/Early_Warning_Dissemination.md: 4256
#
# ----------------------------------------------------
#
# Scraping: Emergency Operations
# Saved to service_md_12/Emergency_Operations.md: 900
#
# ----------------------------------------------------
#
# Scraping: Issuing Permits for Timber Transport
# Saved to service_md_12/Issuing_Permits_for_Timber_Transport.md: 2111
#
# ----------------------------------------------------
#
# Scraping: Implement Environmental Protection Licensing Procedure
# Saved to service_md_12/Implement_Environmental_Protection_Licensing_Procedure.md: 4956
#
# ----------------------------------------------------
#
# Scraping: How to Dispose Your Electronic Waste in an Environmental Friendly Manner
# Saved to service_md_12/How_to_Dispose_Your_Electronic_Waste_in_an_Environmental_Friendly_Manner.md: 6159
#
# ----------------------------------------------------
#
# Scraping: Bamboo Plants
# Saved to service_md_12/Bamboo_Plants.md: 905
#
# ----------------------------------------------------
#
# Scraping: Registration of Timber Based Enterprises
# Saved to service_md_12/Registration_of_Timber_Based_Enterprises.md: 4483
#
# ----------------------------------------------------
#
# Scraping: Extension of Registration of Timber Base Enterprises
# Saved to service_md_12/Extension_of_Registration_of_Timber_Base_Enterprises.md: 2432
#
# ----------------------------------------------------
#
# Scraping: Obtaining Environmental Approval for Projects
# Saved to service_md_12/Obtaining_Environmental_Approval_for_Projects.md: 7366
#
# ----------------------------------------------------
#
# Scraping: Resolve Public Complaints Related to Environmental Pollution
# Saved to service_md_12/Resolve_Public_Complaints_Related_to_Environmental_Pollution.md: 1368
#
# ----------------------------------------------------
#
# Scraping: Awareness Programmes
# Saved to service_md_12/Awareness_Programmes.md: 3537
#
# ----------------------------------------------------
#
# Scraping: Short Term Training Programmes Relevant to Meteorological Field and Resources
# Saved to service_md_12/Short_Term_Training_Programmes_Relevant_to_Meteorological_Field_and_Resources.md: 1533
#
# ----------------------------------------------------
#
# Scraping: Issuing Permits to Export Furniture
# Saved to service_md_12/Issuing_Permits_to_Export_Furniture.md: 1738
#
# ----------------------------------------------------
#
# Scraping: Issuing of Transport permit for Furniture
# Saved to service_md_12/Issuing_of_Transport_permit_for_Furniture.md: 2105
#
# ----------------------------------------------------
#
# Scraping: Implement Environmental Recommendation Procedure
# Saved to service_md_12/Implement_Environmental_Recommendation_Procedure.md: 1995
#
# ----------------------------------------------------
#
# Scraping: Bamboo Plants
# Saved to service_md_12/Bamboo_Plants.md: 905
#
# ----------------------------------------------------
#
# Scraping: Obtaining Detailed Meteorological Reports for Insurance Claims
# Saved to service_md_12/Obtaining_Detailed_Meteorological_Reports_for_Insurance_Claims.md: 1367
#
# ----------------------------------------------------
#
# Scraping: Obtaining Meteorological Data
# Saved to service_md_12/Obtaining_Meteorological_Data.md: 2192
#
# ----------------------------------------------------
#
# Scraping: Weather Information and Forecasts (Daily/ Short Time)
# Saved to service_md_12/Weather_Information_and_Forecasts__Daily__Short_Time_.md: 1805
#
# ----------------------------------------------------
#
# Scraping: Astronomical Data/ Tides and Other data/ Meteorological Publications
# Saved to service_md_12/Astronomical_Data__Tides_and_Other_data__Meteorological_Publications.md: 1129
#
# ----------------------------------------------------
#
# Scraping: Installation of and Graduation of Meteorological Equipment
# Saved to service_md_12/Installation_of_and_Graduation_of_Meteorological_Equipment.md: 1406
#
# ----------------------------------------------------
#
# Scraping: Educational Visits and Awareness Programmes for School Children.
# Saved to service_md_12/Educational_Visits_and_Awareness_Programmes_for_School_Children_.md: 1352
#
# ----------------------------------------------------
#
# Scraping: Handling the Weather and Climate Scientific Studies and Projects
# Saved to service_md_12/Handling_the_Weather_and_Climate_Scientific_Studies_and_Projects.md: 1411
#
# ----------------------------------------------------
#
# Scraping: Contribution for the Meteorological Exhibitions
# Saved to service_md_12/Contribution_for_the_Meteorological_Exhibitions.md: 1455
#
# ----------------------------------------------------
#
# Scraping: Reserve a Circuit Bungalow
# Saved to service_md_12/Reserve_a_Circuit_Bungalow.md: 1082
#
# ----------------------------------------------------
#
# Scraping: Mega Constructions in Buffer Zones of National Reserves
# Saved to service_md_12/Mega_Constructions_in_Buffer_Zones_of_National_Reserves.md: 783
#
# ----------------------------------------------------
#
# Scraping: Registration of Domesticated Elephants/Tusks
# Saved to service_md_12/Registration_of_Domesticated_Elephants_Tusks.md: 873
#
# ----------------------------------------------------

# %%
import shutil

shutil.make_archive(
    base_name=output_dir,
    format="zip",
    root_dir=output_dir
)
# Out:
# '/content/service_md_12.zip'

# %%
content.to_csv(f"gic_data_content_{main_category_id}.csv", index=False)

# %%
import numpy as np

df = content.copy()
df["content_file"] = df["content_file"].replace("", np.nan)
df["is_scraped"] = df["content_file"].notna()

summary = (
    df.groupby(["main_category_id", "main_category"])
      .agg(
          scraped=("content_file", lambda x: x.notna().sum()),
          not_scraped=("content_file", lambda x: x.isna().sum()),
      )
      .reset_index()
)
summary
# Out:
#     main_category_id                        main_category  scraped  \
# 0                  1                 Education & Training       66
# 1                  2        Housing, Property & Utilities       45
# 2                  3             Banking, Tax & Insurance       48
# 3                  4           Travel, Tourism &  Lesiure       41
# 4                  5                Justice, Law & Rights       62
# 5                  6               Employment Information       32
# 6                  7  Health, Well Being & Social Service       93
# 7                  8   Agriculture, Livestock & Fisheries      101
# 8                  9              Citizen's Registrations       36
# 9                 10           Trade, Business & Industry      127
# 10                11                Communication & Media       44
# 11                12                          Environment       38
#
#     not_scraped
# 0             2
# 1             0
# 2             7
# 3             6
# 4             1
# 5             5
# 6             0
# 7             2
# 8             1
# 9             2
# 10            2
# 11            0

# %%
total_scraped = summary["scraped"].sum()
total_not_scraped = summary["not_scraped"].sum()

total_summary = {
    "scraped": total_scraped,
    "not_scraped": total_not_scraped,
    "total": total_scraped + total_not_scraped
}

print(total_summary)
# Out:
# {'scraped': np.int64(733), 'not_scraped': np.int64(28), 'total': np.int64(761)}

# %%
unscraped = content[
    content["content_file"].isna() | (content["content_file"] == "")
]

for _, row in unscraped.iterrows():
    print(row["main_category"])
    print(row["service"], "->")
    print(row["serviceLink"])
    print("\n----------------------------------------\n")
# Out:
# Education & Training
# Official Languages Proficiencies Exam ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=601&catid=20&task=info
#
# ----------------------------------------
#
# Education & Training
# Proficiencies Exam for Other Languages ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=606&catid=20&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Safe Deposit Lockers ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=772&catid=90&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# BOC I-net Facility ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=790&catid=90&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Issuing Crackers for Public ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1101&catid=90&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Obtain Educational Loans ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=813&catid=25&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Small & Medium Scale Loans ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1860&catid=25&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Obtaining a Temporary VAT Certificate ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=865&catid=26&task=info
#
# ----------------------------------------
#
# Banking, Tax & Insurance
# Obtaining Tax clearance Certificate ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=867&catid=26&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# State Children's  Contest &  Art Festival ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=637&catid=91&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# Visit to Haldummulla Herbal Garden ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=955&catid=91&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# Reach to Pinnawala Elephant Orphanage ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1164&catid=91&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# Visit to Other Herbal Gardens ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1213&catid=91&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# Aquarium of National Zoological Gardens ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=607&catid=91&task=info
#
# ----------------------------------------
#
# Travel, Tourism &  Lesiure
# Issue of New Passports ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1765&catid=27&task=info
#
# ----------------------------------------
#
# Justice, Law & Rights
# Apply for Postal Voting ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1134&catid=33&task=info
#
# ----------------------------------------
#
# Employment Information
# Short Term Training Programmes Relevant to Meteorological Field and Resources ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=768&catid=86&task=info
#
# ----------------------------------------
#
# Employment Information
# Change of officers of a registered Trade Union ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1126&catid=86&task=info
#
# ----------------------------------------
#
# Employment Information
# Widows’/Widowers’ & Orphans’ Pension Scheme ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=506&catid=38&task=info
#
# ----------------------------------------
#
# Employment Information
# Civil Pensions Scheme ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=494&catid=38&task=info
#
# ----------------------------------------
#
# Employment Information
# Public Service Provident Fund ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=495&catid=38&task=info
#
# ----------------------------------------
#
# Agriculture, Livestock & Fisheries
# Extension &Training: Advisory service for establishing commercial farms ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=1351&catid=47&task=info
#
# ----------------------------------------
#
# Agriculture, Livestock & Fisheries
# Sign Language Service ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=679&catid=48&task=info
#
# ----------------------------------------
#
# Citizen's Registrations
# Issuing certificates confirming the citizenship of Indian Origin persons, on their request ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=396&catid=49&task=info
#
# ----------------------------------------
#
# Trade, Business & Industry
# Dosimetry Calibration Laboratory service ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=2030&catid=59&task=info
#
# ----------------------------------------
#
# Trade, Business & Industry
# Dosimetry Calibration Laboratory service ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=2030&catid=60&task=info
#
# ----------------------------------------
#
# Communication & Media
# Publications ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=617&catid=81&task=info
#
# ----------------------------------------
#
# Communication & Media
# Language Translation ->
# https://gic.gov.lk/gic/index.php/en/component/info/?id=609&catid=81&task=info
#
# ----------------------------------------

# %% [markdown]
# ## Scraped data stats after manually reviewed and added content of missing services

# %%
import pandas as pd

final_data = pd.read_csv("gic_data_content_final.csv")
final_data.head()
# Out:
#    main_category_id         main_category             subcategory  \
# 0                 1  Education & Training  Education Publications
# 1                 1  Education & Training  Education Publications
# 2                 1  Education & Training  Education Publications
# 3                 1  Education & Training  Education Publications
# 4                 1  Education & Training  Education Publications
#
#                                              service  \
# 0                             Sales Outlets of Books
# 1                                Museum Publications
# 2  Services of Establishment Unit of Educational ...
# 3  Services of Information Technology Unit of Edu...
# 4  Warehouses of Educational  Publications Depart...
#
#                                          serviceLink  \
# 0  https://gic.gov.lk/gic/index.php/en/component/...
# 1  https://gic.gov.lk/gic/index.php/en/component/...
# 2  https://gic.gov.lk/gic/index.php/en/component/...
# 3  https://gic.gov.lk/gic/index.php/en/component/...
# 4  https://gic.gov.lk/gic/index.php/en/component/...
#
#                                         content_file
# 0             service_md_1/Sales_Outlets_of_Books.md
# 1                service_md_1/Museum_Publications.md
# 2  service_md_1/Services_of_Establishment_Unit_of...
# 3  service_md_1/Services_of_Information_Technolog...
# 4  service_md_1/Warehouses_of_Educational__Public...

# %%
summary = (
    final_data.groupby(["main_category_id", "main_category"])
      .agg(
          scraped=("content_file", lambda x: (x != "-").sum()),
          not_scraped=("content_file", lambda x: (x == "-").sum()),
      )
      .reset_index()
)

summary
# Out:
#     main_category_id                        main_category  scraped  \
# 0                  1                 Education & Training       66
# 1                  2        Housing, Property & Utilities       45
# 2                  3             Banking, Tax & Insurance       52
# 3                  4           Travel, Tourism &  Lesiure       46
# 4                  5                Justice, Law & Rights       63
# 5                  6               Employment Information       34
# 6                  7  Health, Well Being & Social Service       93
# 7                  8   Agriculture, Livestock & Fisheries      102
# 8                  9              Citizen's Registrations       37
# 9                 10           Trade, Business & Industry      127
# 10                11                Communication & Media       44
# 11                12                          Environment       38
#
#     not_scraped
# 0             2
# 1             0
# 2             3
# 3             1
# 4             0
# 5             3
# 6             0
# 7             1
# 8             0
# 9             2
# 10            2
# 11            0

# %%
total_scraped = summary["scraped"].sum()
total_not_scraped = summary["not_scraped"].sum()

total_summary = {
    "scraped": total_scraped,
    "not_scraped": total_not_scraped,
    "total": total_scraped + total_not_scraped
}

print(total_summary)
# Out:
# {'scraped': np.int64(747), 'not_scraped': np.int64(14), 'total': np.int64(761)}

# %%
summary.to_csv("gic_data_content_final_summary.csv", index=False)

# %% [markdown]
# ## Extract subcategory id and service id for each service

# %%
import pandas as pd

final_data = pd.read_csv("gic_data_content_final.csv")
final_data.head()
# Out:
#    main_category_id         main_category             subcategory  \
# 0                 1  Education & Training  Education Publications
# 1                 1  Education & Training  Education Publications
# 2                 1  Education & Training  Education Publications
# 3                 1  Education & Training  Education Publications
# 4                 1  Education & Training  Education Publications
#
#                                              service  \
# 0                             Sales Outlets of Books
# 1                                Museum Publications
# 2  Services of Establishment Unit of Educational ...
# 3  Services of Information Technology Unit of Edu...
# 4  Warehouses of Educational  Publications Depart...
#
#                                          serviceLink  \
# 0  https://gic.gov.lk/gic/index.php/en/component/...
# 1  https://gic.gov.lk/gic/index.php/en/component/...
# 2  https://gic.gov.lk/gic/index.php/en/component/...
# 3  https://gic.gov.lk/gic/index.php/en/component/...
# 4  https://gic.gov.lk/gic/index.php/en/component/...
#
#                                         content_file
# 0             service_md_1/Sales_Outlets_of_Books.md
# 1                service_md_1/Museum_Publications.md
# 2  service_md_1/Services_of_Establishment_Unit_of...
# 3  service_md_1/Services_of_Information_Technolog...
# 4  service_md_1/Warehouses_of_Educational__Public...

# %%
final_data['sub_category_id'] = 0
final_data['service_id'] = 0
final_data.iloc[0]['serviceLink']
# Out:
# 'https://gic.gov.lk/gic/index.php/en/component/info/?id=665&catid=87&task=info'

# %%
from urllib.parse import urlparse, parse_qs
import pandas as pd

def extract_ids(service_url):
    parsed = urlparse(service_url)
    params = parse_qs(parsed.query)

    return pd.Series({
        "service_id": params.get("id", [None])[0],
        "sub_category_id": params.get("catid", [None])[0],
    })

# Apply once (vectorized)
final_data[["service_id", "sub_category_id"]] = (
    final_data["serviceLink"]
    .apply(extract_ids)
)

# Convert to integers safely
final_data["service_id"] = pd.to_numeric(final_data["service_id"], errors="coerce")
final_data["sub_category_id"] = pd.to_numeric(final_data["sub_category_id"], errors="coerce")

# %%
final_data.head()
# Out:
#    main_category_id         main_category             subcategory  \
# 0                 1  Education & Training  Education Publications
# 1                 1  Education & Training  Education Publications
# 2                 1  Education & Training  Education Publications
# 3                 1  Education & Training  Education Publications
# 4                 1  Education & Training  Education Publications
#
#                                              service  \
# 0                             Sales Outlets of Books
# 1                                Museum Publications
# 2  Services of Establishment Unit of Educational ...
# 3  Services of Information Technology Unit of Edu...
# 4  Warehouses of Educational  Publications Depart...
#
#                                          serviceLink  \
# 0  https://gic.gov.lk/gic/index.php/en/component/...
# 1  https://gic.gov.lk/gic/index.php/en/component/...
# 2  https://gic.gov.lk/gic/index.php/en/component/...
# 3  https://gic.gov.lk/gic/index.php/en/component/...
# 4  https://gic.gov.lk/gic/index.php/en/component/...
#
#                                         content_file  sub_category_id  \
# 0             service_md_1/Sales_Outlets_of_Books.md               87
# 1                service_md_1/Museum_Publications.md               87
# 2  service_md_1/Services_of_Establishment_Unit_of...               87
# 3  service_md_1/Services_of_Information_Technolog...               87
# 4  service_md_1/Warehouses_of_Educational__Public...               87
#
#    service_id
# 0         665
# 1        1481
# 2         662
# 3         659
# 4         664

# %%
final_data.to_csv("gic_data_final_ids_extracted.csv", index=False)

# %%
final_data["key"] = (
    final_data["main_category_id"].astype(str)
    + "-" +
    final_data["sub_category_id"].astype(str)
    + "-" +
    final_data["service_id"].astype(str)
)

duplicates = final_data[
    final_data["key"].duplicated(keep=False)
]

duplicates
# Out:
# Empty DataFrame
# Columns: [main_category_id, main_category, subcategory, service, serviceLink, content_file, sub_category_id, service_id, key]
# Index: []

# %%
final_data.to_csv("gic_data_final_with_key.csv", index=False)
