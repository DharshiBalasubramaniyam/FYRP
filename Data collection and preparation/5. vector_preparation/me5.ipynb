# %% [markdown]
# ## Install Dependencies

# %%
# !pip install langchain langchain-community langchain-core pinecone fastembed langchain-pinecone

# %%
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer
from langchain.embeddings.base import Embeddings
from google.colab import userdata
import time
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %% [markdown]
# ## Load embedding model

# %%
class MultilingualE5Embeddings(Embeddings):
    def __init__(self, model_name: str = "intfloat/multilingual-e5-large"):
        self.model = SentenceTransformer(model_name)

    def embed_documents(self, texts):
        # E5 requires "passage:" prefix for documents
        return [
            self.model.encode(f"passage: {text}").tolist()
            for text in texts
        ]

    def embed_query(self, text):
        # E5 requires "query:" prefix for queries
        return self.model.encode(f"query: {text}").tolist()

# %%
embedding_model = MultilingualE5Embeddings()

# %% [markdown]
# ## Create index in vector store

# %%
pc = Pinecone(api_key=userdata.get('PINECONE_API_KEY'))
existing_indexes = [index_info["name"] for index_info in pc.list_indexes()]
pc_index_name = "gic-me5"

if pc_index_name in existing_indexes:
  print(f"Vector store index '{pc_index_name}' found. Deleting existing...")
  pc.delete_index(pc_index_name)


print(f"Creating new vector store...")

pc.create_index(
  name=pc_index_name,
  dimension=1024,
  metric="cosine",
  spec=ServerlessSpec(
    cloud="aws",
    region="us-east-1"
  )
)

while not pc.describe_index(pc_index_name).status['ready']:  # Wait for the index to be ready
  time.sleep(1)
  print(f"Successfully created vector store index '{pc_index_name}'.")
# Out:
# Vector store index 'gic-me5' found. Deleting existing...
# Creating new vector store...

# %% [markdown]
# ## Store contexts in vector store index

# %%
import pandas as pd

data = pd.read_csv("gic_data_contexts_final_with_meta.csv")
print(len(data))
# Out:
# 1699

# %%
data.head()
# Out:
#     context_id                                      context_title  \
# 0   1-87-665-1  Educational Publications Department Book Sales...
# 1  1-87-1481-1          Publication Prices - Sinhala Publications
# 2  1-87-1481-2          Publication Prices - English Publications
# 3  1-87-1481-3  Publication Prices - English and Tamil Publica...
# 4   1-87-662-1     Departmental Administration and Record Keeping
#
#                                      context_content  main_category_id  \
# 0  There are 6 sales outlets of books, successful...                 1
# 1  Publication Price Sinhala Publications Rs. Cts...                 1
# 2  English Publications\n21. Some Sinhala Combati...                 1
# 3  36. The Pleistocene of Ceylon 390 00\n37. Colo...                 1
# 4  1. Maintaining the personal files of the offic...                 1
#
#      main_category_name       sub_category_name  sub_category_id  \
# 0  Education & Training  Education Publications               87
# 1  Education & Training  Education Publications               87
# 2  Education & Training  Education Publications               87
# 3  Education & Training  Education Publications               87
# 4  Education & Training  Education Publications               87
#
#                                         service_name  service_id  \
# 0                             Sales Outlets of Books         665
# 1                                Museum Publications        1481
# 2                                Museum Publications        1481
# 3                                Museum Publications        1481
# 4  Services of Establishment Unit of Educational ...         662
#
#                                         service_link  \
# 0  https://gic.gov.lk/gic/index.php/en/component/...
# 1  https://gic.gov.lk/gic/index.php/en/component/...
# 2  https://gic.gov.lk/gic/index.php/en/component/...
# 3  https://gic.gov.lk/gic/index.php/en/component/...
# 4  https://gic.gov.lk/gic/index.php/en/component/...
#
#                                context_with_metadata
# 0  Service: Sales Outlets of Books\nMain Category...
# 1  Service: Museum Publications\nMain Category: E...
# 2  Service: Museum Publications\nMain Category: E...
# 3  Service: Museum Publications\nMain Category: E...
# 4  Service: Services of Establishment Unit of Edu...

# %%
from langchain_core.documents import Document

docs = []

for i, row in data.iterrows():
    if i % 20 == 0:
        print(f"Adding context {i}")

    doc = Document(
        page_content=row["context_with_metadata"],
        metadata={
            "context_id": row["context_id"],
            "context_title": row["context_title"],
            "main_category_id": int(row["main_category_id"]),
            "main_category_name": row["main_category_name"],
            "sub_category_id": int(row["sub_category_id"]),
            "sub_category_name": row["sub_category_name"],
            "service_id": int(row["service_id"]),
            "service_name": row["service_name"],
            "service_link": row["service_link"],
            "language": "en"
        }
    )

    docs.append(doc)

print(len(docs))
# Out:
# Adding context 0
# Adding context 20
# Adding context 40
# Adding context 60
# Adding context 80
# Adding context 100
# Adding context 120
# Adding context 140
# Adding context 160
# Adding context 180
# Adding context 200
# Adding context 220
# Adding context 240
# Adding context 260
# Adding context 280
# Adding context 300
# Adding context 320
# Adding context 340
# Adding context 360
# Adding context 380
# Adding context 400
# Adding context 420
# Adding context 440
# Adding context 460
# Adding context 480
# Adding context 500
# Adding context 520
# Adding context 540
# Adding context 560
# Adding context 580
# Adding context 600
# Adding context 620
# Adding context 640
# Adding context 660
# Adding context 680
# Adding context 700
# Adding context 720
# Adding context 740
# Adding context 760
# Adding context 780
# Adding context 800
# Adding context 820
# Adding context 840
# Adding context 860
# Adding context 880
# Adding context 900
# Adding context 920
# Adding context 940
# Adding context 960
# Adding context 980
# Adding context 1000
# Adding context 1020
# Adding context 1040
# Adding context 1060
# Adding context 1080
# Adding context 1100
# Adding context 1120
# Adding context 1140
# Adding context 1160
# Adding context 1180
# Adding context 1200
# Adding context 1220
# Adding context 1240
# Adding context 1260
# Adding context 1280
# Adding context 1300
# Adding context 1320
# Adding context 1340
# Adding context 1360
# Adding context 1380
# Adding context 1400
# Adding context 1420
# Adding context 1440
# Adding context 1460
# Adding context 1480
# Adding context 1500
# Adding context 1520
# Adding context 1540
# Adding context 1560
# Adding context 1580
# Adding context 1600
# Adding context 1620
# Adding context 1640
# Adding context 1660
# Adding context 1680
# 1699

# %%
index = pc.Index(pc_index_name)
vector_store = PineconeVectorStore(index=index, embedding=embedding_model)

# %%
pc.describe_index("gic-me5")["dimension"]
# Out:
# 1024

# %%
embeddings = []
for i, doc in enumerate(docs):
    if i % 20 == 0:
        print(f"Computing embedding {i}")
    emb = embedding_model.embed_documents([doc.page_content])[0]
    embeddings.append(emb)
# Out:
# Computing embedding 0
# Computing embedding 20
# Computing embedding 40
# Computing embedding 60
# Computing embedding 80
# Computing embedding 100
# Computing embedding 120
# Computing embedding 140
# Computing embedding 160
# Computing embedding 180
# Computing embedding 200
# Computing embedding 220
# Computing embedding 240
# Computing embedding 260
# Computing embedding 280
# Computing embedding 300
# Computing embedding 320
# Computing embedding 340
# Computing embedding 360
# Computing embedding 380
# Computing embedding 400
# Computing embedding 420
# Computing embedding 440
# Computing embedding 460
# Computing embedding 480
# Computing embedding 500
# Computing embedding 520
# Computing embedding 540
# Computing embedding 560
# Computing embedding 580
# Computing embedding 600
# Computing embedding 620
# Computing embedding 640
# Computing embedding 660
# Computing embedding 680
# Computing embedding 700
# Computing embedding 720
# Computing embedding 740
# Computing embedding 760
# Computing embedding 780
# Computing embedding 800
# Computing embedding 820
# Computing embedding 840
# Computing embedding 860
# Computing embedding 880
# Computing embedding 900
# Computing embedding 920
# Computing embedding 940
# Computing embedding 960
# Computing embedding 980
# Computing embedding 1000
# Computing embedding 1020
# Computing embedding 1040
# Computing embedding 1060
# Computing embedding 1080
# Computing embedding 1100
# Computing embedding 1120
# Computing embedding 1140
# Computing embedding 1160
# Computing embedding 1180
# Computing embedding 1200
# Computing embedding 1220
# Computing embedding 1240
# Computing embedding 1260
# Computing embedding 1280
# Computing embedding 1300
# Computing embedding 1320
# Computing embedding 1340
# Computing embedding 1360
# Computing embedding 1380
# Computing embedding 1400
# Computing embedding 1420
# Computing embedding 1440
# Computing embedding 1460
# Computing embedding 1480
# Computing embedding 1500
# Computing embedding 1520
# Computing embedding 1540
# Computing embedding 1560
# Computing embedding 1580
# Computing embedding 1600
# Computing embedding 1620
# Computing embedding 1640
# Computing embedding 1660
# Computing embedding 1680

# %%
print(len(embeddings))
# Out:
# 1699

# %%
vectors = [
    (str(i), emb, doc.metadata)
    for i, (doc, emb) in enumerate(zip(docs, embeddings))
]

# %%
batch_size = 25
index = pc.Index(pc_index_name)

for i in range(0, len(vectors), batch_size):
    batch = vectors[i:i+batch_size]
    print(f"Uploading batch {i} - {i + len(batch)}")
    index.upsert(vectors=batch)
# Out:
# Uploading batch 0 - 25
# Uploading batch 25 - 50
# Uploading batch 50 - 75
# Uploading batch 75 - 100
# Uploading batch 100 - 125
# Uploading batch 125 - 150
# Uploading batch 150 - 175
# Uploading batch 175 - 200
# Uploading batch 200 - 225
# Uploading batch 225 - 250
# Uploading batch 250 - 275
# Uploading batch 275 - 300
# Uploading batch 300 - 325
# Uploading batch 325 - 350
# Uploading batch 350 - 375
# Uploading batch 375 - 400
# Uploading batch 400 - 425
# Uploading batch 425 - 450
# Uploading batch 450 - 475
# Uploading batch 475 - 500
# Uploading batch 500 - 525
# Uploading batch 525 - 550
# Uploading batch 550 - 575
# Uploading batch 575 - 600
# Uploading batch 600 - 625
# Uploading batch 625 - 650
# Uploading batch 650 - 675
# Uploading batch 675 - 700
# Uploading batch 700 - 725
# Uploading batch 725 - 750
# Uploading batch 750 - 775
# Uploading batch 775 - 800
# Uploading batch 800 - 825
# Uploading batch 825 - 850
# Uploading batch 850 - 875
# Uploading batch 875 - 900
# Uploading batch 900 - 925
# Uploading batch 925 - 950
# Uploading batch 950 - 975
# Uploading batch 975 - 1000
# Uploading batch 1000 - 1025
# Uploading batch 1025 - 1050
# Uploading batch 1050 - 1075
# Uploading batch 1075 - 1100
# Uploading batch 1100 - 1125
# Uploading batch 1125 - 1150
# Uploading batch 1150 - 1175
# Uploading batch 1175 - 1200
# Uploading batch 1200 - 1225
# Uploading batch 1225 - 1250
# Uploading batch 1250 - 1275
# Uploading batch 1275 - 1300
# Uploading batch 1300 - 1325
# Uploading batch 1325 - 1350
# Uploading batch 1350 - 1375
# Uploading batch 1375 - 1400
# Uploading batch 1400 - 1425
# Uploading batch 1425 - 1450
# Uploading batch 1450 - 1475
# Uploading batch 1475 - 1500
# Uploading batch 1500 - 1525
# Uploading batch 1525 - 1550
# Uploading batch 1550 - 1575
# Uploading batch 1575 - 1600
# Uploading batch 1600 - 1625
# Uploading batch 1625 - 1650
# Uploading batch 1650 - 1675
# Uploading batch 1675 - 1699

# %%
stats = index.describe_index_stats()
print("Pinecone index stats:", stats)
# Out:
# Pinecone index stats: {'dimension': 1024,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 1699}},
#  'total_vector_count': 1699,
#  'vector_type': 'dense'}

# %% [markdown]
# # Add "text" metadata for embeddings

# %%
pc = Pinecone(api_key=userdata.get('PINECONE_API_KEY'))
pc_index_name = "gic-me5"

# %%
index = pc.Index(pc_index_name)
vector_store = PineconeVectorStore(index=index, embedding=embedding_model)

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 1699}},
#  'total_vector_count': 1699,
#  'vector_type': 'dense'}

# %%
index.update(
    id="0",
    set_metadata={
        "text": docs[0].page_content,
    }
)
# Out:
# {}

# %%
for i, doc in enumerate(docs):
    if i % 20 == 0:
        print(f"Updating text {i}")
    index.update(
      id=str(i),
      set_metadata={
          "text": doc.page_content,
      }
    )
# Out:
# Updating text 0
# Updating text 20
# Updating text 40
# Updating text 60
# Updating text 80
# Updating text 100
# Updating text 120
# Updating text 140
# Updating text 160
# Updating text 180
# Updating text 200
# Updating text 220
# Updating text 240
# Updating text 260
# Updating text 280
# Updating text 300
# Updating text 320
# Updating text 340
# Updating text 360
# Updating text 380
# Updating text 400
# Updating text 420
# Updating text 440
# Updating text 460
# Updating text 480
# Updating text 500
# Updating text 520
# Updating text 540
# Updating text 560
# Updating text 580
# Updating text 600
# Updating text 620
# Updating text 640
# Updating text 660
# Updating text 680
# Updating text 700
# Updating text 720
# Updating text 740
# Updating text 760
# Updating text 780
# Updating text 800
# Updating text 820
# Updating text 840
# Updating text 860
# Updating text 880
# Updating text 900
# Updating text 920
# Updating text 940
# Updating text 960
# Updating text 980
# Updating text 1000
# Updating text 1020
# Updating text 1040
# Updating text 1060
# Updating text 1080
# Updating text 1100
# Updating text 1120
# Updating text 1140
# Updating text 1160
# Updating text 1180
# Updating text 1200
# Updating text 1220
# Updating text 1240
# Updating text 1260
# Updating text 1280
# Updating text 1300
# Updating text 1320
# Updating text 1340
# Updating text 1360
# Updating text 1380
# Updating text 1400
# Updating text 1420
# Updating text 1440
# Updating text 1460
# Updating text 1480
# Updating text 1500
# Updating text 1520
# Updating text 1540
# Updating text 1560
# Updating text 1580
# Updating text 1600
# Updating text 1620
# Updating text 1640
# Updating text 1660
# Updating text 1680

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 1699}},
#  'total_vector_count': 1699,
#  'vector_type': 'dense'}
